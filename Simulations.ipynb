# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/JonathanBechtel/optimized-app/master/train.csv')

# %% [markdown]
# #### Step 1:  Creating All of the GroupBy Output For The Bar & Line Charts

# %%
# get the lists of columns we are going to use
cols = df.columns.tolist()
num_cols = df.select_dtypes(include=np.number).columns.tolist()
# make a directory to store all of the files
# !mkdir groupbys

# %%
y_axis = ['OverallQual', 'OverallCond', 'GrLivArea', 'SalePrice', 'LotArea', 'SalePrice']
x_axis = ['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'OverallCond', 'YearBuilt', 'FullBath', 'HalfBath', 'GarageType']

# %%
# !mkdir groupbys

# %%
# write a loop that creates all of the groupings and exports them to csv files
for col in x_axis:
    for num_col in y_axis:
        if col != num_col:
            grouping = df.groupby(col)[num_col].mean().reset_index()
            file_name = f"{col}_{num_col}.csv"
            grouping.to_csv(f'groupbys/{file_name}', index=False)

# %% [markdown]
# ### Step 2:  Creating All of the Boxplots for Seaborn

# %%
# !mkdir boxplots
# !cd boxplots

# %%
# dict that will hold the chart figures
import pickle
i = 1
for col in x_axis:
    for num_col in y_axis:
        if col != num_col:
            print(f"Round {i}, Making Boxplot For: {col}, {num_col}")
            name = f"{col}_{num_col}.pkl"
            chart = sns.catplot(x=col, y=num_col, kind='box', aspect=2, data=df)
            if df[col].nunique() > 8:
                chart.set_xticklabels(rotation=90)
            with open(name, 'wb') as boxplots:
                pickle.dump(chart.fig, boxplots)
            i += 1
# Out:
# Round 1, Making Boxplot For: MSSubClass, OverallQual
# Round 2, Making Boxplot For: MSSubClass, OverallCond
# Round 3, Making Boxplot For: MSSubClass, GrLivArea
# Round 4, Making Boxplot For: MSSubClass, SalePrice
# Round 5, Making Boxplot For: MSSubClass, LotArea
# Round 6, Making Boxplot For: MSSubClass, SalePrice
# Round 7, Making Boxplot For: MSZoning, OverallQual
# Round 8, Making Boxplot For: MSZoning, OverallCond
# Round 9, Making Boxplot For: MSZoning, GrLivArea
# Round 10, Making Boxplot For: MSZoning, SalePrice
# Round 11, Making Boxplot For: MSZoning, LotArea
# Round 12, Making Boxplot For: MSZoning, SalePrice
# Round 13, Making Boxplot For: Neighborhood, OverallQual
# Round 14, Making Boxplot For: Neighborhood, OverallCond
# Round 15, Making Boxplot For: Neighborhood, GrLivArea
# Round 16, Making Boxplot For: Neighborhood, SalePrice
# Round 17, Making Boxplot For: Neighborhood, LotArea
# Round 18, Making Boxplot For: Neighborhood, SalePrice
# Round 19, Making Boxplot For: OverallQual, OverallCond
# Round 20, Making Boxplot For: OverallQual, GrLivArea
# Round 21, Making Boxplot For: OverallQual, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 22, Making Boxplot For: OverallQual, LotArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 23, Making Boxplot For: OverallQual, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 24, Making Boxplot For: OverallCond, OverallQual
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 25, Making Boxplot For: OverallCond, GrLivArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 26, Making Boxplot For: OverallCond, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 27, Making Boxplot For: OverallCond, LotArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 28, Making Boxplot For: OverallCond, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 29, Making Boxplot For: YearBuilt, OverallQual
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 30, Making Boxplot For: YearBuilt, OverallCond
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 31, Making Boxplot For: YearBuilt, GrLivArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 32, Making Boxplot For: YearBuilt, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 33, Making Boxplot For: YearBuilt, LotArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 34, Making Boxplot For: YearBuilt, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 35, Making Boxplot For: FullBath, OverallQual
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 36, Making Boxplot For: FullBath, OverallCond
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 37, Making Boxplot For: FullBath, GrLivArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 38, Making Boxplot For: FullBath, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 39, Making Boxplot For: FullBath, LotArea
# Round 40, Making Boxplot For: FullBath, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 41, Making Boxplot For: HalfBath, OverallQual
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 42, Making Boxplot For: HalfBath, OverallCond
# Round 43, Making Boxplot For: HalfBath, GrLivArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 44, Making Boxplot For: HalfBath, SalePrice
# Round 45, Making Boxplot For: HalfBath, LotArea
# Round 46, Making Boxplot For: HalfBath, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 47, Making Boxplot For: GarageType, OverallQual
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 48, Making Boxplot For: GarageType, OverallCond
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 49, Making Boxplot For: GarageType, GrLivArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 50, Making Boxplot For: GarageType, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 51, Making Boxplot For: GarageType, LotArea
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# Round 52, Making Boxplot For: GarageType, SalePrice
# C:\Users\Jonat\Anaconda\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
